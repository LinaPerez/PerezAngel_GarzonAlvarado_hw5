# %%
from scipy.io import wavfile%pylab inlineimport matplotlib.pyplot as pltimport numpy as nfrom scipy.fftpack import fft, fftfreqfrom scipy import fftpackimport cmath
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
fs, sig = wavfile.read('play.wav')plot(sig);

# %%
npoints = size(sig)print npoints
# Out:
# 96000

# %%
fft_rand_signal = fft(sig) / npoints freq = fftfreq(npoints, 1) plt.plot(freq,np.abs(fft_rand_signal))plt.xlim(-0.05,0.05)
# Out:
# (-0.05, 0.05)

# %%
half_n = np.ceil(npoints)fft_rand_signal_half = (2.0) * fft_rand_signal[:half_n]freq_half = freq[:half_n]scatter(freq_half, log10(np.absolute(fft_rand_signal_half)**2)) plt.xlim([0.01,0.5])plt.ylim([-6,1])
# Out:
# (-6, 1)

# %%
f1=fft_rand_signal_half/np.absolute(fft_rand_signal_half)plot(np.absolute(f1))

# %%
#le sacamos la transformada inversa de fourier y lo graficamos, encontramos el ruido blancoclean_f = ifft(f1) xx=clean_f.realplot(float16(xx))

# %%
pylab.plot(sig, 'r')pylab.plot(clean_f.real*10000)pylab.show()

# %%
wavfile.write('white_noise.wav', fs, float16(xx))

# %%
#shape(clean_f)print type(sig[1]), type((xx[1]))
# Out:
# <type 'numpy.int16'> <type 'numpy.float64'>

# %% [markdown]
# Pink Noise

# %%
pink = (1/freq)*15 #amplificamos la amplitud para que suene mas duroplot(pink)plt.xlim(-0.05,80)plt.ylim(-0.1, 100000)
# Out:
# (-0.1, 100000)

# %%
pylab.plot(sig*10, 'r')pylab.plot(pink)pylab.show()

# %%
wavfile.write('pink_noise.wav', fs, float16(pink))

# %%
print size(pink), type(float16(pink))
# Out:
# 96000 <type 'numpy.ndarray'>
