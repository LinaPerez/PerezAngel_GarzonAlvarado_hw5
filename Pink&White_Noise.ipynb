# %%
from scipy.io import wavfile%pylab inlineimport matplotlib.pyplot as pltimport numpy as npfrom numpy import pifrom scipy.fftpack import fft, fftfreqfrom scipy import fftpackimport cmath
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
fs, sig = wavfile.read('play.wav')plot(sig);

# %%
npoints = size(sig)print npoints
# Out:
# 96000

# %%
fft_rand_signal = fft(sig) / npoints freq = fftfreq(npoints, 1) plt.plot(freq,np.abs(fft_rand_signal))plt.xlim(-0.05,0.05)
# Out:
# (-0.05, 0.05)

# %%
half_n = np.ceil(npoints)fft_rand_signal_half = (2.0) * fft_rand_signal[:half_n]freq_half = freq[:half_n]scatter(freq_half, log10(np.absolute(fft_rand_signal_half)**2)) plt.xlim([0.01,0.5])plt.ylim([-6,1])
# Out:
# (-6, 1)

# %%
f1=fft_rand_signal_half/np.absolute(fft_rand_signal_half)plot(np.absolute(f1))

# %%
#le sacamos la transformada inversa de fourier y lo graficamos, encontramos el ruido blancoclean_f = ifft(f1) plot(float16(xx))

# %%
pylab.plot(sig, 'r')pylab.plot(clean_f.real*1000000)pylab.show()

# %%
#mirar como se guarda el white noise en un .wavxx=clean_f.realwavfile.write('white_noise.wav', fs, float16(xx))

# %%
#shape(clean_f)print type(sig[1]), type((xx[1]))
# Out:
# <type 'numpy.int16'> <type 'numpy.float64'>

# %% [markdown]
# Pink Noise

# %%
pink = 1/freq_half plot(pink)plt.xlim(-0.05,80)
# Out:
# -c:2: RuntimeWarning: divide by zero encountered in divide
# (-0.05, 80)

# %%
wavfile.write('pink_noise.wav', fs, (pink))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/lina/Documents/MetodosComputacionales/Tarea5/PerezAngel_GarzonAlvarado_hw5/<ipython-input-65-aeb8cf3a3a48> in <module>()
# ----> 1 wavfile.write('pink_noise.wav', fs, (pink))
#
# /usr/lib/python2.7/dist-packages/scipy/io/wavfile.pyc in write(filename, rate, data)
#     159     # fmt chunk
#
#     160     fid.write(asbytes('fmt '))
# --> 161     if data.ndim == 1:
#     162         noc = 1
#     163     else:
#
# AttributeError: 'function' object has no attribute 'ndim'

# %%
print size(pink), type(pink)
# Out:
# 1 <type 'function'>

# %%
#pasar pink a un float o algo asi
