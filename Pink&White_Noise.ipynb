# %%
from scipy.io import wavfile%pylab inlineimport matplotlib.pyplot as pltimport numpy as npfrom numpy import pifrom scipy.fftpack import fft, fftfreqfrom scipy import fftpack
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %%
fs, sig = wavfile.read('play.wav')plot(sig);

# %%
npoints = size(sig)print npoints
# Out:
# 96000

# %%
fft_rand_signal = fft(sig) / npoints freq = fftfreq(npoints, 1) plt.plot(freq,np.abs(fft_rand_signal))plt.xlim(-0.05,0.05)
# Out:
# (-0.05, 0.05)

# %%
half_n = np.ceil(npoints/2.0)fft_rand_signal_half = (2.0) * fft_rand_signal[:half_n]freq_half = freq[:half_n]scatter(freq_half, log10(np.absolute(fft_rand_signal_half)**2)) plt.xlim([0.01,0.5])plt.ylim([-6,1])
# Out:
# (-6, 1)

# %%
f1=fft_rand_signal_half/np.absolute(fft_rand_signal_half)plot(np.absolute(f1))

# %%
#le sacamos la transformada inversa de fourier y lo graficamos, encontramos el ruido blancoclean_f = ifft(f1) plot(clean_f)

# %%
pylab.plot(sig, 'r')pylab.plot(clean_f)pylab.show()
